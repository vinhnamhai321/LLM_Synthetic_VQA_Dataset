# %%
# Load model directly
from transformers import AutoModelForCausalLM
model = AutoModelForCausalLM.from_pretrained("microsoft/llava-med-v1.5-mistral-7b", dtype="auto")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /network-volume/miniconda3/envs/llava_env/lib/python3.10/site-packages/transformers/models/auto/configuration_auto.py:1457, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1456 try:
# -> 1457     config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1458 except KeyError:
#
# File /network-volume/miniconda3/envs/llava_env/lib/python3.10/site-packages/transformers/models/auto/configuration_auto.py:1160, in _LazyConfigMapping.__getitem__(self, key)
#    1159 if key not in self._mapping:
# -> 1160     raise KeyError(key)
#    1161 value = self._mapping[key]
#
# KeyError: 'llava_mistral'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load model directly
#       2 from transformers import AutoModelForCausalLM
# ----> 3 model = AutoModelForCausalLM.from_pretrained("microsoft/llava-med-v1.5-mistral-7b", dtype="auto")
#
# File /network-volume/miniconda3/envs/llava_env/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:319, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     316 if kwargs.get("quantization_config") is not None:
#     317     _ = kwargs.pop("quantization_config")
# --> 319 config, kwargs = AutoConfig.from_pretrained(
#     320     pretrained_model_name_or_path,
#     321     return_unused_kwargs=True,
#     322     code_revision=code_revision,
#     323     _commit_hash=commit_hash,
#     324     **hub_kwargs,
#     325     **kwargs,
#     326 )
#     328 # if torch_dtype=auto was passed here, ensure to pass it on
#     329 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File /network-volume/miniconda3/envs/llava_env/lib/python3.10/site-packages/transformers/models/auto/configuration_auto.py:1459, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1457         config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1458     except KeyError:
# -> 1459         raise ValueError(
#    1460             f"The checkpoint you are trying to load has model type `{config_dict['model_type']}` "
#    1461             "but Transformers does not recognize this architecture. This could be because of an "
#    1462             "issue with the checkpoint, or because your version of Transformers is out of date.\n\n"
#    1463             "You can update Transformers with the command `pip install --upgrade transformers`. If this "
#    1464             "does not work, and the checkpoint is very new, then there may not be a release version "
#    1465             "that supports this model yet. In this case, you can get the most up-to-date code by installing "
#    1466             "Transformers from source with the command "
#    1467             "`pip install git+https://github.com/huggingface/transformers.git`"
#    1468         )
#    1469     return config_class.from_dict(config_dict, **unused_kwargs)
#    1471 raise ValueError(
#    1472     f"Unrecognized model in {pretrained_model_name_or_path}. "
#    1473     f"Should have a `model_type` key in its {CONFIG_NAME}."
#    1474 )
#
# ValueError: The checkpoint you are trying to load has model type `llava_mistral` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.
#
# You can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`
